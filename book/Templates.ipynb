// %% [markdown]
// # Detour

// %% [markdown]
// # Benoit
//
// Formula
// ben

// %%
%use lib-ext(0.12.0-93)
LATEX(
    """
\Huge
z_{n+1} = z_n^2 + c
"""
)
// Out:
// <img src="data:image/svg+xml;base64,..."/>

// %% [markdown]
// # Aristid
//
// *rock*

// %% [markdown]
// # Tortoise
//
// koch

// %% [markdown]
// weed

// %% [markdown]
// plant

// %% [markdown]
// xmas

// %% [markdown]
// wiki

// %% [markdown]
// plants

// %% [markdown]
// # Stochastic Squirrel
// squirrel

// %% [markdown]
// # Seedlings to Forest
// forest
// fireflies
