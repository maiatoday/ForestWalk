// %%
fun xx() {
    val axiom = "F"
    val rules = mapOf('F' to "F[F]-F+F[--F]+F-F")
    val iterations = 1
    val result = lSystem(axiom, rules, iterations)
    println(result)
}

// %%
xx()
// Out:
// F[F]-F+F[--F]+F-F

// %%
import java.awt.image.BufferedImage

fun dd(): BufferedImage {
    val axiom = "F"
    val rules = mapOf('F' to "F[F]-F+F[--F]+F-F")
    val iterations = 5
    val result = lSystem(axiom, rules, iterations)
    return drawLSystem(result, iterations)
    }

// %%
dd()
// Out:
// class java.awt.image.BufferedImage: 1000x1000 px
